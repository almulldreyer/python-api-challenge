# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import datetime
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output csv file
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If city is unique, add to cities list
    if city not in cities:
        cities.append(city)

# Print the city count
len(cities)
# Out:
# 633

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Perform API Calls
# Perform a weather check on each city using a series of successive API calls.
# Include a print log of each city as it'sbeing processed (with the city number and city name).
url_main = "http://api.openweathermap.org/data/2.5/weather?"
query_url = url_main + "appid=" + weather_api_key + "&q=" + 'Miami'
weather = requests.get(query_url).json()
weather

# Define url
url_main = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&"
#http://api.openweathermap.org/data/2.5/weather?

# Create counters
record_count = 1
set_count = 1
columns = ["City", "Cloudiness", "Country", "Date", "Humidity", "Lat", "Lng", "Max Temp (F)", "Wind Speed"]
city_data = pd.DataFrame(columns = columns)
print("-----------------------------")
print("Beginning Data Retrieval.")
print("-----------------------------")

# Set iteration
for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

# Set index and row in df.interrows():
    print(f"Processing City {record_count} of Set {set_count} | {city}")
    record_count +=1

# Define url for query
    query_url = url_main + "appid=" + weather_api_key + "&q=" + city
    
    try:
        weather = requests.get(query_url).json()
        city_clouds = weather['clouds']['all']
        country = weather['sys']['country']
        date = weather['dt']
        city_humidity = weather['main']['humidity']
        #city_temp = weather['main']['temp']
        lat = weather['coord']['lat']
        lon = weather['coord']['lon']
        city_max_temp = weather['main']['temp_max']
        city_wind_speed = weather['wind']['speed']    
        
        # Append city into city_info
        city_data = city_data.append({"City": city,
                                      "Cloudiness" : city_clouds,
                                      "Country" : country,
                                      "Date" : date,
                                      "Humidity" : city_humidity,
                                      "Lat" : lat,
                                      "Lng" : lon,
                                      "Max Temp (F)" : city_max_temp,
                                      "Wind Speed" : city_wind_speed,
                                     }, ignore_index=True)
        
    except:
        print("City not found. Skipping...")
        pass
    
print("-----------------------------")
print("Data Retrieval Complete.")
print("-----------------------------")
# Out:
# -----------------------------
# Beginning Data Retrieval.
# -----------------------------
# Processing City 1 of Set 1 | sholapur
# Processing City 2 of Set 1 | inirida
# Processing City 3 of Set 1 | plettenberg bay
# Processing City 4 of Set 1 | kapaa
# Processing City 5 of Set 1 | dolores
# Processing City 6 of Set 1 | jamestown
# Processing City 7 of Set 1 | punta arenas
# Processing City 8 of Set 1 | inhambane
# Processing City 9 of Set 1 | amderma
# City not found. Skipping...
# Processing City 10 of Set 1 | arbazh
# Processing City 11 of Set 1 | busselton
# Processing City 12 of Set 1 | batagay
# Processing City 13 of Set 1 | mount gambier
# Processing City 14 of Set 1 | saint-pierre
# Processing City 15 of Set 1 | upernavik
# Processing City 16 of Set 1 | ushuaia
# Processing City 17 of Set 1 | talnakh
# Processing City 18 of Set 1 | vaini
# Processing City 19 of Set 1 | thompson
# Processing City 20 of Set 1 | rikitea
# Processing City 21 of Set 1 | taolanaro
# City not found. Skipping...
# Processing City 22 of Set 1 | barrow
# Processing City 23 of Set 1 | kuningan
# Processing City 24 of Set 1 | butaritari
# Processing City 25 of Set 1 | santa rosa
# Processing City 26 of Set 1 | bluff
# Processing City 27 of Set 1 | severo-kurilsk
# Processing City 28 of Set 1 | vila
# Processing City 29 of Set 1 | vao
# Processing City 30 of Set 1 | kidal
# Processing City 31 of Set 1 | ocean city
# Processing City 32 of Set 1 | orvieto
# Processing City 33 of Set 1 | poronaysk
# Processing City 34 of Set 1 | klaksvik
# Processing City 35 of Set 1 | tuktoyaktuk
# Processing City 36 of Set 1 | yellowknife
# Processing City 37 of Set 1 | port alfred
# Processing City 38 of Set 1 | pisco
# Processing City 39 of Set 1 | tiksi
# Processing City 40 of Set 1 | sambava
# Processing City 41 of Set 1 | mamakan
# Processing City 42 of Set 1 | taonan
# Processing City 43 of Set 1 | mayo
# Processing City 44 of Set 1 | siniscola
# Processing City 45 of Set 1 | artyk
# City not found. Skipping...
# Processing City 46 of Set 1 | kalawit
# Processing City 47 of Set 1 | torbay
# Processing City 48 of Set 1 | bathsheba
# Processing City 49 of Set 1 | longyearbyen
# Processing City 50 of Set 1 | hilo
# Processing City 0 of Set 2 | aswan
# Processing City 1 of Set 2 | price
# Processing City 2 of Set 2 | jinchang
# Processing City 3 of Set 2 | port macquarie
# Processing City 4 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing City 5 of Set 2 | sorland
# Processing City 6 of Set 2 | eureka
# Processing City 7 of Set 2 | lavrentiya
# Processing City 8 of Set 2 | avila
# Processing City 9 of Set 2 | hermanus
# Processing City 10 of Set 2 | long beach
# Processing City 11 of Set 2 | san cristobal
# Processing City 12 of Set 2 | kaprijke
# Processing City 13 of Set 2 | bambous virieux
# Processing City 14 of Set 2 | praya
# Processing City 15 of Set 2 | pombas
# Processing City 16 of Set 2 | vaitupu
# City not found. Skipping...
# Processing City 17 of Set 2 | coquimbo
# Processing City 18 of Set 2 | saskylakh
# Processing City 19 of Set 2 | nishihara
# Processing City 20 of Set 2 | sumbawa
# City not found. Skipping...
# Processing City 21 of Set 2 | areosa
# Processing City 22 of Set 2 | mataura
# Processing City 23 of Set 2 | pevek
# Processing City 24 of Set 2 | codrington
# Processing City 25 of Set 2 | albany
# Processing City 26 of Set 2 | novyy urgal
# Processing City 27 of Set 2 | ribeira grande
# Processing City 28 of Set 2 | carnarvon
# Processing City 29 of Set 2 | roald
# Processing City 30 of Set 2 | samana
# Processing City 31 of Set 2 | namibe
# Processing City 32 of Set 2 | lagodekhi
# Processing City 33 of Set 2 | la marque
# Processing City 34 of Set 2 | vicksburg
# Processing City 35 of Set 2 | atuona
# Processing City 36 of Set 2 | qaanaaq
# Processing City 37 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing City 38 of Set 2 | hobart
# Processing City 39 of Set 2 | port lincoln
# Processing City 40 of Set 2 | mahebourg
# Processing City 41 of Set 2 | avarua
# Processing City 42 of Set 2 | ijaki
# City not found. Skipping...
# Processing City 43 of Set 2 | bousse
# Processing City 44 of Set 2 | hithadhoo
# Processing City 45 of Set 2 | kos
# Processing City 46 of Set 2 | souillac
# Processing City 47 of Set 2 | adamas
# Processing City 48 of Set 2 | east london
# Processing City 49 of Set 2 | vila franca do campo
# Processing City 0 of Set 3 | ponta do sol
# Processing City 1 of Set 3 | oriximina
# Processing City 2 of Set 3 | sabha
# Processing City 3 of Set 3 | port augusta
# Processing City 4 of Set 3 | hofn
# Processing City 5 of Set 3 | bengkulu
# Processing City 6 of Set 3 | kodiak
# Processing City 7 of Set 3 | gela
# Processing City 8 of Set 3 | kaitangata
# Processing City 9 of Set 3 | hunza
# City not found. Skipping...
# Processing City 10 of Set 3 | priboj
# Processing City 11 of Set 3 | norman wells
# Processing City 12 of Set 3 | ostrovnoy
# Processing City 13 of Set 3 | lucapa
# Processing City 14 of Set 3 | maragogi
# Processing City 15 of Set 3 | egvekinot
# Processing City 16 of Set 3 | airai
# Processing City 17 of Set 3 | cairo montenotte
# Processing City 18 of Set 3 | sitka
# Processing City 19 of Set 3 | coihaique
# Processing City 20 of Set 3 | auki
# Processing City 21 of Set 3 | tabiauea
# City not found. Skipping...
# Processing City 22 of Set 3 | lagoa
# Processing City 23 of Set 3 | bredasdorp
# Processing City 24 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing City 25 of Set 3 | cape town
# Processing City 26 of Set 3 | puerto ayora
# Processing City 27 of Set 3 | vilyuysk
# Processing City 28 of Set 3 | grand river south east
# City not found. Skipping...
# Processing City 29 of Set 3 | new norfolk
# Processing City 30 of Set 3 | nusaybin
# Processing City 31 of Set 3 | tello
# Processing City 32 of Set 3 | massaguet
# Processing City 33 of Set 3 | marystown
# Processing City 34 of Set 3 | road town
# Processing City 35 of Set 3 | brigantine
# Processing City 36 of Set 3 | sarangani
# Processing City 37 of Set 3 | comodoro rivadavia
# Processing City 38 of Set 3 | constitucion
# Processing City 39 of Set 3 | sobolevo
# Processing City 40 of Set 3 | khatanga
# Processing City 41 of Set 3 | launceston
# Processing City 42 of Set 3 | hamilton
# Processing City 43 of Set 3 | ola
# Processing City 44 of Set 3 | nouadhibou
# Processing City 45 of Set 3 | luderitz
# Processing City 46 of Set 3 | koumac
# Processing City 47 of Set 3 | naze
# Processing City 48 of Set 3 | banff
# Processing City 49 of Set 3 | flinders
# Processing City 0 of Set 4 | bonavista
# Processing City 1 of Set 4 | quatre cocos
# Processing City 2 of Set 4 | zaranj
# Processing City 3 of Set 4 | merauke
# Processing City 4 of Set 4 | hornepayne
# Processing City 5 of Set 4 | sur
# Processing City 6 of Set 4 | nikolskoye
# Processing City 7 of Set 4 | northam
# Processing City 8 of Set 4 | kovdor
# Processing City 9 of Set 4 | zabolotovka
# Processing City 10 of Set 4 | skibbereen
# Processing City 11 of Set 4 | chagda
# City not found. Skipping...
# Processing City 12 of Set 4 | mundo nuevo
# Processing City 13 of Set 4 | vostok
# Processing City 14 of Set 4 | vestmannaeyjar
# Processing City 15 of Set 4 | nara
# Processing City 16 of Set 4 | luwuk
# Processing City 17 of Set 4 | ulaangom
# Processing City 18 of Set 4 | lianran
# Processing City 19 of Set 4 | wexford
# Processing City 20 of Set 4 | tasiilaq
# Processing City 21 of Set 4 | sulangan
# Processing City 22 of Set 4 | zanjan
# Processing City 23 of Set 4 | bolshegrivskoye
# City not found. Skipping...
# Processing City 24 of Set 4 | eenhana
# Processing City 25 of Set 4 | tondano
# Processing City 26 of Set 4 | bethel
# Processing City 27 of Set 4 | slave lake
# Processing City 28 of Set 4 | manali
# Processing City 29 of Set 4 | san patricio
# Processing City 30 of Set 4 | jiazi
# Processing City 31 of Set 4 | meyungs
# City not found. Skipping...
# Processing City 32 of Set 4 | igarka
# Processing City 33 of Set 4 | luganville
# Processing City 34 of Set 4 | cepu
# Processing City 35 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing City 36 of Set 4 | ulladulla
# Processing City 37 of Set 4 | haapiti
# Processing City 38 of Set 4 | sonqor
# Processing City 39 of Set 4 | antofagasta
# Processing City 40 of Set 4 | iqaluit
# Processing City 41 of Set 4 | barentsburg
# City not found. Skipping...
# Processing City 42 of Set 4 | fernie
# Processing City 43 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing City 44 of Set 4 | stillwater
# Processing City 45 of Set 4 | olonets
# Processing City 46 of Set 4 | fereydun kenar
# Processing City 47 of Set 4 | coxim
# Processing City 48 of Set 4 | tilichiki
# Processing City 49 of Set 4 | salalah
# Processing City 0 of Set 5 | kutum
# Processing City 1 of Set 5 | eskisehir
# Processing City 2 of Set 5 | lompoc
# Processing City 3 of Set 5 | marrakesh
# Processing City 4 of Set 5 | wanning
# Processing City 5 of Set 5 | biak
# Processing City 6 of Set 5 | acarau
# Processing City 7 of Set 5 | shibarghan
# City not found. Skipping...
# Processing City 8 of Set 5 | jalu
# Processing City 9 of Set 5 | leningradskiy
# Processing City 10 of Set 5 | provideniya
# Processing City 11 of Set 5 | santa eulalia del rio
# City not found. Skipping...
# Processing City 12 of Set 5 | sidi ali
# Processing City 13 of Set 5 | port hedland
# Processing City 14 of Set 5 | bama
# Processing City 15 of Set 5 | isangel
# Processing City 16 of Set 5 | port blair
# Processing City 17 of Set 5 | dalinghe
# City not found. Skipping...
# Processing City 18 of Set 5 | yakeshi
# Processing City 19 of Set 5 | douglas
# Processing City 20 of Set 5 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing City 21 of Set 5 | kresttsy
# Processing City 22 of Set 5 | nanortalik
# Processing City 23 of Set 5 | victoria
# Processing City 24 of Set 5 | komsomolskiy
# Processing City 25 of Set 5 | waddan
# Processing City 26 of Set 5 | stockton-on-tees
# Processing City 27 of Set 5 | fare
# Processing City 28 of Set 5 | edd
# Processing City 29 of Set 5 | nizhniy kuranakh
# Processing City 30 of Set 5 | haibowan
# City not found. Skipping...
# Processing City 31 of Set 5 | grindavik
# Processing City 32 of Set 5 | labuhan
# Processing City 33 of Set 5 | mar del plata
# Processing City 34 of Set 5 | pankovka
# Processing City 35 of Set 5 | mahon
# Processing City 36 of Set 5 | bulolo
# Processing City 37 of Set 5 | bacuit
# City not found. Skipping...
# Processing City 38 of Set 5 | belyy yar
# Processing City 39 of Set 5 | billings
# Processing City 40 of Set 5 | clyde river
# Processing City 41 of Set 5 | waingapu
# Processing City 42 of Set 5 | sovetskiy
# Processing City 43 of Set 5 | olafsvik
# Processing City 44 of Set 5 | omboue
# Processing City 45 of Set 5 | mpanda
# Processing City 46 of Set 5 | marcona
# City not found. Skipping...
# Processing City 47 of Set 5 | cherskiy
# Processing City 48 of Set 5 | laguna
# Processing City 49 of Set 5 | padang
# Processing City 0 of Set 6 | dingle
# Processing City 1 of Set 6 | camopi
# Processing City 2 of Set 6 | tarakan
# Processing City 3 of Set 6 | kirakira
# Processing City 4 of Set 6 | trat
# Processing City 5 of Set 6 | saint-michel-des-saints
# Processing City 6 of Set 6 | muyezerskiy
# Processing City 7 of Set 6 | bandarbeyla
# Processing City 8 of Set 6 | akyab
# Processing City 9 of Set 6 | ife
# Processing City 10 of Set 6 | la ronge
# Processing City 11 of Set 6 | karamea
# City not found. Skipping...
# Processing City 12 of Set 6 | cayenne
# Processing City 13 of Set 6 | port keats
# Processing City 14 of Set 6 | terenga
# City not found. Skipping...
# Processing City 15 of Set 6 | chokurdakh
# Processing City 16 of Set 6 | georgetown
# Processing City 17 of Set 6 | arman
# Processing City 18 of Set 6 | dubti
# Processing City 19 of Set 6 | arlit
# Processing City 20 of Set 6 | portland
# Processing City 21 of Set 6 | tabou
# Processing City 22 of Set 6 | katangli
# Processing City 23 of Set 6 | yilan
# Processing City 24 of Set 6 | tete
# Processing City 25 of Set 6 | wodonga
# Processing City 26 of Set 6 | victor harbor
# Processing City 27 of Set 6 | vardo
# Processing City 28 of Set 6 | lorengau
# Processing City 29 of Set 6 | seoul
# Processing City 30 of Set 6 | sumbe
# Processing City 31 of Set 6 | chama
# Processing City 32 of Set 6 | iquitos
# Processing City 33 of Set 6 | beasain
# Processing City 34 of Set 6 | tiznit
# Processing City 35 of Set 6 | tabialan
# City not found. Skipping...
# Processing City 36 of Set 6 | hobbs
# Processing City 37 of Set 6 | mandalgovi
# Processing City 38 of Set 6 | malanville
# Processing City 39 of Set 6 | kokopo
# Processing City 40 of Set 6 | ankang
# Processing City 41 of Set 6 | bobcaygeon
# Processing City 42 of Set 6 | erzin
# Processing City 43 of Set 6 | sao joao da barra
# Processing City 44 of Set 6 | castro
# Processing City 45 of Set 6 | praia da vitoria
# Processing City 46 of Set 6 | san juan
# Processing City 47 of Set 6 | pingzhuang
# Processing City 48 of Set 6 | ayautla
# City not found. Skipping...
# Processing City 49 of Set 6 | beringovskiy
# Processing City 0 of Set 7 | parabel
# Processing City 1 of Set 7 | port elizabeth
# Processing City 2 of Set 7 | maceio
# Processing City 3 of Set 7 | gedo
# Processing City 4 of Set 7 | namatanai
# Processing City 5 of Set 7 | arraial do cabo
# Processing City 6 of Set 7 | pochutla
# Processing City 7 of Set 7 | sainte-marie
# Processing City 8 of Set 7 | babu
# Processing City 9 of Set 7 | maarianhamina
# Processing City 10 of Set 7 | dikson
# Processing City 11 of Set 7 | hay river
# Processing City 12 of Set 7 | north bend
# Processing City 13 of Set 7 | simbahan
# Processing City 14 of Set 7 | udayagiri
# Processing City 15 of Set 7 | kavaratti
# Processing City 16 of Set 7 | bulgan
# Processing City 17 of Set 7 | kota belud
# Processing City 18 of Set 7 | tomatlan
# Processing City 19 of Set 7 | itarema
# Processing City 20 of Set 7 | belushya guba
# City not found. Skipping...
# Processing City 21 of Set 7 | vila velha
# Processing City 22 of Set 7 | olsztyn
# Processing City 23 of Set 7 | port hardy
# Processing City 24 of Set 7 | taoudenni
# Processing City 25 of Set 7 | manono
# Processing City 26 of Set 7 | coffs harbour
# Processing City 27 of Set 7 | hvide sande
# Processing City 28 of Set 7 | sidhi
# Processing City 29 of Set 7 | khandyga
# Processing City 30 of Set 7 | te anau
# Processing City 31 of Set 7 | qandala
# Processing City 32 of Set 7 | buala
# Processing City 33 of Set 7 | mayor pablo lagerenza
# Processing City 34 of Set 7 | kruisfontein
# Processing City 35 of Set 7 | dawson creek
# Processing City 36 of Set 7 | tuatapere
# Processing City 37 of Set 7 | mogadishu
# Processing City 38 of Set 7 | hasaki
# Processing City 39 of Set 7 | noginsk
# Processing City 40 of Set 7 | honiara
# Processing City 41 of Set 7 | tabuk
# Processing City 42 of Set 7 | doha
# Processing City 43 of Set 7 | mantua
# Processing City 44 of Set 7 | thabazimbi
# Processing City 45 of Set 7 | sale
# Processing City 46 of Set 7 | bikaner
# Processing City 47 of Set 7 | saint-denis
# Processing City 48 of Set 7 | privokzalnyy
# City not found. Skipping...
# Processing City 49 of Set 7 | waldkraiburg
# Processing City 0 of Set 8 | prince rupert
# Processing City 1 of Set 8 | dukat
# Processing City 2 of Set 8 | kyra
# Processing City 3 of Set 8 | husavik
# Processing City 4 of Set 8 | svencionys
# Processing City 5 of Set 8 | aykhal
# Processing City 6 of Set 8 | balsas
# Processing City 7 of Set 8 | charagua
# Processing City 8 of Set 8 | raga
# Processing City 9 of Set 8 | bonthe
# Processing City 10 of Set 8 | los llanos de aridane
# Processing City 11 of Set 8 | kamennogorsk

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Creating city dataframe
city_data.count()

# Display DataFrame of city_data
city_data.head()

# Save data as csv file
city_data.to_csv("../cities_output2.csv", encoding="utf-8", index=False)

city_data.head()

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Define date
date = time.strftime("%m/%d/%Y")

# Set plot parameters
plt.scatter(city_data["Lat"], city_data["Max Temp (F)"],
            edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="cities")
plt.title(f"City Latitude vs. Temperature {date}", fontsize = "12")
plt.xlabel(f"Latitude", fontsize="14")
plt.ylabel(f"Max Temperature (F)", fontsize="14")
plt.grid(True)
print("Plot shows that temperature decreases the further from the equator.")
           
plt.savefig("Temperature.png")

plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Set plot parameters
timestamp = time.strftime("%m/%d/%Y")

plt.scatter(city_data["Lat"], city_data["Humidity"],
            edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="cities")
plt.title(f"City Latitude vs. Humidity {timestamp}", fontsize = "12")
plt.xlabel(f"Latitude", fontsize="14")
plt.ylabel(f"Humidity (%)", fontsize="14")
plt.grid(True)
plt.savefig("Latitude vs Temperature (F).png")
plt.show()
print("The plot shows that humidity is predominantly 80% to 100% between latitudes -40 to 60.")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
timestamp = time.strftime("%m/%d/%Y")

plt.scatter(city_data["Lat"], city_data["Cloudiness"], marker = "o", color = "blue",edgecolor = "black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.title(f"City Latitude vs. Cloudiness ({timestamp})")
plt.savefig("Cloudiness.png")
plt.show()
print("This scatter plot does not present any discernible findings.")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
timestamp = time.strftime("%m/%d/%Y")

plt.scatter(city_data["Lat"], city_data["Wind Speed"], marker = "o", color = "blue",edgecolor = "black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Wind Speed(mph)")
plt.title(f"City Latitude vs. Wind Speed ({timestamp})")
plt.grid(True)
plt.savefig("Wind Speed.png")
plt.show()
print("The plot shows that wind speed does not correlate with latitude.")

# %% [markdown]
# ## Linear Regression

# %%
# Add Linear regression to plot

def linear_reg_plot(x_values,y_values):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,(x_values.median(),y_values.median()),fontsize=10,color="red")
    plt.xlabel("Latitude")
    print(f"The r-squared is: {rvalue}")
    plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
Northern_hemisphere = city_data.loc[pd.to_numeric(city_data["Lat"]).astype(float) > 0, :]
Southern_hemisphere = city_data.loc[pd.to_numeric(city_data["Lat"]).astype(float) < 0, :]

# Northern Hemisphere and Max Temp

x_values = pd.to_numeric(Northern_hemisphere['Lat']).astype(float)
y_values = pd.to_numeric(Northern_hemisphere['Max Temp (F)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y =" + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}.")

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, "r-")
plt.annotate(line_eq,(6,10),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a negative correlation.")
print("In the Northern Hemisphere, the temperature decreases with increased latitude.")
      
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Define Southern Hemisphere and Max Temp

x_values = pd.to_numeric(Southern_hemisphere['Lat']).astype(float)
y_values = pd.to_numeric(Southern_hemisphere['Max Temp (F)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y =" + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}.")

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, "r-")
plt.annotate(line_eq,(6,10),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a positive correlation.")
print("In the Southern Hemisphere, temperatures increased the closer to the equator one is.")
      
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere and Humidity

x_values = pd.to_numeric(Northern_hemisphere['Lat']).astype(float)
y_values = pd.to_numeric(Northern_hemisphere['Humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y =" + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}.")

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, "r-")
plt.annotate(line_eq,(6,10),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a positive correlation.")
print("Northern hemisphere humidity increases slightly with higher latitude.")
      
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Southern Hemisphere and Humidity

x_values = pd.to_numeric(Southern_hemisphere['Lat']).astype(float)
y_values = pd.to_numeric(Southern_hemisphere['Humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y =" + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}.")

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, "r-")
plt.annotate(line_eq,(6,10),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a positive correlation.")
print("In the Southern Hemisphere, humidity slightly increases closer to the equator.")
      
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere and Cloudiness

x_values = pd.to_numeric(Northern_hemisphere['Lat']).astype(float)
y_values = pd.to_numeric(Northern_hemisphere['Cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y =" + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}.")

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, "r-")
plt.annotate(line_eq,(6,10),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Northern Hemisphere - Cloudiness vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a positive correlation.")
print("Cloudiness increases with higher latitude in the Northern Hemisphere.")
      
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Define Southern Hemisphere and Cloudiness

x_values = pd.to_numeric(Southern_hemisphere['Lat']).astype(float)
y_values = pd.to_numeric(Southern_hemisphere['Cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y =" + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}.")

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, "r-")
plt.annotate(line_eq,(6,10),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a positive correlation.")
print("Cloudiness slightly increases the closer to the equator in the Southern Hemisphere.")
      
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Northern Hemisphere and Cloudiness

x_values = pd.to_numeric(Northern_hemisphere['Lat']).astype(float)
y_values = pd.to_numeric(Northern_hemisphere['Wind Speed']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y =" + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}.")

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, "r-")
plt.annotate(line_eq,(6,10),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a neutral/slightly positive correlation.")
print("In the Northern Hemisphere, wind speed has a slight increase with higher latitude.")
      
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Define Southern Hemisphere and Cloudiness

x_values = pd.to_numeric(Southern_hemisphere['Lat']).astype(float)
y_values = pd.to_numeric(Southern_hemisphere['Wind Speed']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y =" + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}.")

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, "r-")
plt.annotate(line_eq,(6,10),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a negative correlation.")
print("In the Southern Hemisphere, there is a slight decrease in wind speed closer to the equator.")
      
plt.show()
